# %% [markdown]
# # Introduction

# %% [markdown]
# https://medium.com/nlplanet/text-analysis-topic-modelling-with-spacy-gensim-4cd92ef06e06#3363

# %% [markdown]
# # Importing + Data Processing

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (1.13.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim) (6.4.0)

# %%
# !pip install gensim==3.8.3
# Out:
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      ---------------------------------------- 0.0/23.4 MB ? eta -:--:--
#      ---------------------------------------- 0.2/23.4 MB 6.4 MB/s eta 0:00:04
#      - -------------------------------------- 0.6/23.4 MB 7.4 MB/s eta 0:00:04
#      - -------------------------------------- 1.1/23.4 MB 9.6 MB/s eta 0:00:03
#      -- ------------------------------------- 1.6/23.4 MB 9.4 MB/s eta 0:00:03
#      --- ------------------------------------ 2.2/23.4 MB 10.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 2.9/23.4 MB 11.0 MB/s eta 0:00:02
#      ----- ---------------------------------- 3.0/23.4 MB 10.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 3.0/23.4 MB 10.5 MB/s eta 0:00:02
#      ------ --------------------------------- 3.9/23.4 MB 9.5 MB/s eta 0:00:03
#      -------- ------------------------------- 5.1/23.4 MB 12.0 MB/s eta 0:00:02
#      -------- ------------------------------- 5.1/23.4 MB 12.0 MB/s eta 0:00:02
#      --------- ------------------------------ 5.4/23.4 MB 9.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 6.2/23.4 MB 10.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 6.8/23.4 MB 10.6 MB/s eta 0:00:02
#      ------------ --------------------------- 7.1/23.4 MB 10.8 MB/s eta 0:00:02
#      ------------ --------------------------- 7.1/23.4 MB 10.8 MB/s eta 0:00:02
#      -------------- ------------------------- 8.8/23.4 MB 11.2 MB/s eta 0:00:02
#      --------------- ------------------------ 9.1/23.4 MB 11.2 MB/s eta 0:00:02
#      ---------------- ----------------------- 9.6/23.4 MB 11.0 MB/s eta 0:00:02
#      ----------------- --------------------- 10.4/23.4 MB 11.3 MB/s eta 0:00:02
#      ------------------ -------------------- 10.9/23.4 MB 11.9 MB/s eta 0:00:02
#      ------------------- ------------------- 11.6/23.4 MB 12.1 MB/s eta 0:00:01
#      -------------------- ------------------ 12.4/23.4 MB 12.4 MB/s eta 0:00:01
#      --------------------- ----------------- 13.2/23.4 MB 12.1 MB/s eta 0:00:01
#      ---------------------- ---------------- 13.6/23.4 MB 14.2 MB/s eta 0:00:01
#      ----------------------- --------------- 14.2/23.4 MB 13.1 MB/s eta 0:00:01
#      ------------------------ -------------- 14.9/23.4 MB 12.4 MB/s eta 0:00:01
#      -------------------------- ------------ 15.7/23.4 MB 13.9 MB/s eta 0:00:01
#      --------------------------- ----------- 16.4/23.4 MB 13.9 MB/s eta 0:00:01
#      ---------------------------- ---------- 17.0/23.4 MB 13.9 MB/s eta 0:00:01
#      ----------------------------- --------- 17.7/23.4 MB 15.2 MB/s eta 0:00:01
#      ------------------------------ -------- 18.5/23.4 MB 14.9 MB/s eta 0:00:01
#      ------------------------------- ------- 19.2/23.4 MB 14.2 MB/s eta 0:00:01
#      -------------------------------- ------ 19.8/23.4 MB 14.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 20.6/23.4 MB 14.9 MB/s eta 0:00:01
#      ----------------------------------- --- 21.3/23.4 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------ -- 22.0/23.4 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------- - 22.6/23.4 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  23.1/23.4 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  23.4/23.4 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------- 23.4/23.4 MB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.11.3 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim==3.8.3) (1.24.2)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim==3.8.3) (1.13.0)
# Requirement already satisfied: six>=1.5.0 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim==3.8.3) (1.16.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\esthe\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from gensim==3.8.3) (6.4.0)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py): started
#   Building wheel for gensim (setup.py): finished with status 'error'
#   Running setup.py clean for gensim
# Failed to build gensim
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [777 lines of output]
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\__init__.py:81: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-310
#       creating build\lib.win-amd64-cpython-310\gensim
#       copying gensim\downloader.py -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\interfaces.py -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\matutils.py -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\nosy.py -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\utils.py -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\__init__.py -> build\lib.win-amd64-cpython-310\gensim
#       creating build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\bleicorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\csvcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\dictionary.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\hashdictionary.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\indexedcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\lowcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\malletcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\mmcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\sharded_corpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\svmlightcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\textcorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\ucicorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\wikicorpus.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\corpora\__init__.py -> build\lib.win-amd64-cpython-310\gensim\corpora
#       creating build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\atmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\basemodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\base_any2vec.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\callbacks.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\coherencemodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\hdpmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\keyedvectors.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\ldamodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\ldamulticore.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\ldaseqmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\lda_dispatcher.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\lda_worker.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\logentropy_model.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\lsimodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\lsi_dispatcher.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\lsi_worker.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\nmf.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\normmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\phrases.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\poincare.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\rpmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\tfidfmodel.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\translation_matrix.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\utils_any2vec.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\_fasttext_bin.py -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\__init__.py -> build\lib.win-amd64-cpython-310\gensim\models
#       creating build\lib.win-amd64-cpython-310\gensim\parsing
#       copying gensim\parsing\porter.py -> build\lib.win-amd64-cpython-310\gensim\parsing
#       copying gensim\parsing\preprocessing.py -> build\lib.win-amd64-cpython-310\gensim\parsing
#       copying gensim\parsing\__init__.py -> build\lib.win-amd64-cpython-310\gensim\parsing
#       creating build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\glove2word2vec.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wiki.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wikicorpus.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wiki_lemma.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wiki_online.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wiki_online_lemma.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\make_wiki_online_nodebug.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\package_info.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\segment_wiki.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\word2vec2tensor.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\word2vec_standalone.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       copying gensim\scripts\__init__.py -> build\lib.win-amd64-cpython-310\gensim\scripts
#       creating build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\docsim.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\index.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\levenshtein.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\nmslib.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\termsim.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       copying gensim\similarities\__init__.py -> build\lib.win-amd64-cpython-310\gensim\similarities
#       creating build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\atmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\d2vmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\ftmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\hdp.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\ldamodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\ldaseqmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\lsimodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\phrases.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\rpmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\text2bow.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\tfidf.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\w2vmodel.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       copying gensim\sklearn_api\__init__.py -> build\lib.win-amd64-cpython-310\gensim\sklearn_api
#       creating build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\bm25.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\commons.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\graph.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\keywords.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\mz_entropy.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\pagerank_weighted.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\summarizer.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\syntactic_unit.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\textcleaner.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       copying gensim\summarization\__init__.py -> build\lib.win-amd64-cpython-310\gensim\summarization
#       creating build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\basetmtests.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\simspeed.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\simspeed2.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\svd_error.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_aggregation.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_api.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_atmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_big.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_BM25.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_coherencemodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_corpora.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_corpora_dictionary.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_corpora_hashdictionary.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_d2vmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_datatype.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_direct_confirmation.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_doc2vec.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_dtm.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_fasttext.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_fasttext_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_glove2word2vec.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_hdpmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_indirect_confirmation.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_keras_integration.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_keyedvectors.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_keywords.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_ldamallet_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_ldamodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_ldaseqmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_ldavowpalwabbit_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_lda_callback.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_lee.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_logentropy_model.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_lsimodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_matutils.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_miislita.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_nmf.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_normmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_parsing.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_phrases.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_poincare.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_probability_estimation.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_rpmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_scripts.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_segmentation.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_sharded_corpus.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_similarities.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_similarity_metrics.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_sklearn_api.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_summarization.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_text_analysis.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_tfidfmodel.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_tmdiff.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_translation_matrix.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_utils.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_utils_any2vec.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_varembed_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_word2vec.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\test_wordrank_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\utils.py -> build\lib.win-amd64-cpython-310\gensim\test
#       copying gensim\test\__init__.py -> build\lib.win-amd64-cpython-310\gensim\test
#       creating build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\aggregation.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\direct_confirmation_measure.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\indirect_confirmation_measure.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\probability_estimation.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\segmentation.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\text_analysis.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       copying gensim\topic_coherence\__init__.py -> build\lib.win-amd64-cpython-310\gensim\topic_coherence
#       creating build\lib.win-amd64-cpython-310\gensim\viz
#       copying gensim\viz\poincare.py -> build\lib.win-amd64-cpython-310\gensim\viz
#       copying gensim\viz\__init__.py -> build\lib.win-amd64-cpython-310\gensim\viz
#       creating build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\doc2vec.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\fasttext.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\fasttext_wrapper.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\keyedvectors.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\old_saveload.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\word2vec.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       copying gensim\models\deprecated\__init__.py -> build\lib.win-amd64-cpython-310\gensim\models\deprecated
#       creating build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\dtmmodel.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\fasttext.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\ldamallet.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\ldavowpalwabbit.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\varembed.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\wordrank.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       copying gensim\models\wrappers\__init__.py -> build\lib.win-amd64-cpython-310\gensim\models\wrappers
#       running egg_info
#       writing gensim.egg-info\PKG-INFO
#       writing dependency_links to gensim.egg-info\dependency_links.txt
#       writing requirements to gensim.egg-info\requires.txt
#       writing top-level names to gensim.egg-info\top_level.txt
#       reading manifest file 'gensim.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching 'COPYING.LESSER'
#       warning: no files found matching 'ez_setup.py'
#       warning: no files found matching 'gensim\models\doc2vec_inner.c'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info\SOURCES.txt'
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.corpora' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.corpora' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.corpora' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.corpora' to be distributed and are
#               already explicitly excluding 'gensim.corpora' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.models' to be distributed and are
#               already explicitly excluding 'gensim.models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.test.test_data' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.test.test_data.DTM' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.DTM' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.DTM' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.DTM' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.DTM' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.test.test_data.PathLineSentences' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.PathLineSentences' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.PathLineSentences' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.PathLineSentences' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.test.test_data.old_d2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_d2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_d2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_d2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\command\build_py.py:207: _Warning: Package 'gensim.test.test_data.old_w2v_models' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'gensim.test.test_data.old_w2v_models' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'gensim.test.test_data.old_w2v_models' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'gensim.test.test_data.old_w2v_models' to be distributed and are
#               already explicitly excluding 'gensim.test.test_data.old_w2v_models' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying gensim\_matutils.c -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\_matutils.pyx -> build\lib.win-amd64-cpython-310\gensim
#       copying gensim\corpora\_mmreader.c -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\models\_utils_any2vec.c -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec_corpusfile.cpp -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec_inner.cpp -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext_corpusfile.cpp -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext_inner.c -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\nmf_pgd.c -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_corpusfile.cpp -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_inner.c -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\corpora\_mmreader.pyx -> build\lib.win-amd64-cpython-310\gensim\corpora
#       copying gensim\models\_utils_any2vec.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec_corpusfile.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec_inner.pxd -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\doc2vec_inner.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fast_line_sentence.h -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext_corpusfile.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext_inner.pxd -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\fasttext_inner.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\nmf_pgd.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\stdint_wrapper.h -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\voidptr.h -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_corpusfile.pxd -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_corpusfile.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_inner.pxd -> build\lib.win-amd64-cpython-310\gensim\models
#       copying gensim\models\word2vec_inner.pyx -> build\lib.win-amd64-cpython-310\gensim\models
#       creating build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\EN.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\IT.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\OPUS_en_it_europarl_train_one2ten.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\alldata-id-10.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\atmodel_3_0_1_model -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\atmodel_3_0_1_model.expElogbeta.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\atmodel_3_0_1_model.id2word -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\atmodel_3_0_1_model.state -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\bgwiki-latest-pages-articles-shortened.xml.bz2 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\compatible-hash-false.model -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\compatible-hash-true.model -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\cp852_fasttext.bin -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\crime-and-punishment.bin -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\crime-and-punishment.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\crime-and-punishment.vec -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\d2v-lee-v0.13.0 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\doc2vec_old -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\doc2vec_old_sep -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\doc2vec_old_sep.syn0_lockf.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\doc2vec_old_sep.syn1neg.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\dtm_test.dict -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\dtm_test.mm -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\enwiki-latest-pages-articles1.xml-p000000010p000030302-shortened.bz2 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\enwiki-table-markup.xml.bz2 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\euclidean_vectors.bin -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\fasttext_old -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\fasttext_old_sep -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\fasttext_old_sep.syn0_lockf.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\fasttext_old_sep.syn1neg.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\fb-ngrams.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\ft_kv_3.6.0.model.gz -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\ft_model_2.3.0 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\head500.noblanks.cor -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\head500.noblanks.cor.bz2 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\head500.noblanks.cor_tfidf.model -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\head500.noblanks.cor_wordids.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data
# ...
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py2.syn1neg.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3.neg_labels.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3.syn0.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3.syn1neg.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3_4 -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3_4.syn0.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       copying gensim\test\test_data\wordsim353.tsv -> build\lib.win-amd64-cpython-310\gensim\test\test_data
#       creating build\lib.win-amd64-cpython-310\gensim\test\test_data\DTM
#       copying gensim\test\test_data\DTM\ldaseq_3_0_1_model -> build\lib.win-amd64-cpython-310\gensim\test\test_data\DTM
#       copying gensim\test\test_data\DTM\sstats_test.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data\DTM
#       creating build\lib.win-amd64-cpython-310\gensim\test\test_data\PathLineSentences
#       copying gensim\test\test_data\PathLineSentences\1.txt -> build\lib.win-amd64-cpython-310\gensim\test\test_data\PathLineSentences
#       copying gensim\test\test_data\PathLineSentences\2.txt.bz2 -> build\lib.win-amd64-cpython-310\gensim\test\test_data\PathLineSentences
#       creating build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.12.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.12.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.12.2.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.12.3.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.12.4.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.13.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.13.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.13.2.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.13.3.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_0.13.4.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_1.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_1.0.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_2.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_2.1.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_2.2.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_2.3.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_3.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_3.1.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_3.2.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_3.3.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       copying gensim\test\test_data\old_d2v_models\d2v_3.4.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_d2v_models
#       creating build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.12.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.12.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.12.2.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.12.3.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.12.4.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.13.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.13.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.13.2.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.13.3.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_0.13.4.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_1.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_1.0.1.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_2.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_2.1.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_2.2.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_2.3.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_3.0.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_3.1.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_3.2.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_3.3.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       copying gensim\test\test_data\old_w2v_models\w2v_3.4.0.mdl -> build\lib.win-amd64-cpython-310\gensim\test\test_data\old_w2v_models
#       running build_ext
#       building 'gensim.models.word2vec_inner' extension
#       creating build\temp.win-amd64-cpython-310
#       creating build\temp.win-amd64-cpython-310\Release
#       creating build\temp.win-amd64-cpython-310\Release\gensim
#       creating build\temp.win-amd64-cpython-310\Release\gensim\models
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD "-IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include" "-IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include" -IC:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /Tcgensim/models/word2vec_inner.c /Fobuild\temp.win-amd64-cpython-310\Release\gensim/models/word2vec_inner.obj
#       word2vec_inner.c
#       C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#       gensim/models/word2vec_inner.c(2763): warning C4244: '=': conversion from 'unsigned __int64' to '__pyx_t_5numpy_uint32_t', possible loss of data
#       gensim/models/word2vec_inner.c(3753): warning C4244: '=': conversion from 'unsigned __int64' to '__pyx_t_5numpy_uint32_t', possible loss of data
#       gensim/models/word2vec_inner.c(8247): warning C4244: '=': conversion from 'long' to '__pyx_t_6gensim_6models_14word2vec_inner_REAL_t', possible loss of data
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs" "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0" "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\PCbuild\amd64" "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\lib\um\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" /EXPORT:PyInit_word2vec_inner build\temp.win-amd64-cpython-310\Release\gensim/models/word2vec_inner.obj /OUT:build\lib.win-amd64-cpython-310\gensim\models\word2vec_inner.cp310-win_amd64.pyd /IMPLIB:build\temp.win-amd64-cpython-310\Release\gensim/models\word2vec_inner.cp310-win_amd64.lib
#          Creating library build\temp.win-amd64-cpython-310\Release\gensim/models\word2vec_inner.cp310-win_amd64.lib and object build\temp.win-amd64-cpython-310\Release\gensim/models\word2vec_inner.cp310-win_amd64.exp
#       Generating code
#       Finished generating code
#       building 'gensim.corpora._mmreader' extension
#       creating build\temp.win-amd64-cpython-310\Release\gensim\corpora
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe" /c /nologo /O2 /W3 /GL /DNDEBUG /MD "-IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include" "-IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include" -IC:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\include "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include" "-IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include" "-IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt" "-IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt" "-IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um" /Tcgensim/corpora/_mmreader.c /Fobuild\temp.win-amd64-cpython-310\Release\gensim/corpora/_mmreader.obj
#       _mmreader.c
#       gensim/corpora/_mmreader.c(9963): warning C4013: '_PyGen_Send' undefined; assuming extern returning int
#       gensim/corpora/_mmreader.c(9963): warning C4047: '=': 'PyObject *' differs in levels of indirection from 'int'
#       gensim/corpora/_mmreader.c(9968): warning C4047: '=': 'PyObject *' differs in levels of indirection from 'int'
#       gensim/corpora/_mmreader.c(10052): warning C4047: '=': 'PyObject *' differs in levels of indirection from 'int'
#       "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\link.exe" /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs" "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0" "/LIBPATH:C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\PCbuild\amd64" "/LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\lib\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\lib\um\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64" "/LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64" /EXPORT:PyInit__mmreader build\temp.win-amd64-cpython-310\Release\gensim/corpora/_mmreader.obj /OUT:build\lib.win-amd64-cpython-310\gensim\corpora\_mmreader.cp310-win_amd64.pyd /IMPLIB:build\temp.win-amd64-cpython-310\Release\gensim/corpora\_mmreader.cp310-win_amd64.lib
#          Creating library build\temp.win-amd64-cpython-310\Release\gensim/corpora\_mmreader.cp310-win_amd64.lib and object build\temp.win-amd64-cpython-310\Release\gensim/corpora\_mmreader.cp310-win_amd64.exp
#       _mmreader.obj : error LNK2001: unresolved external symbol _PyGen_Send
#       build\lib.win-amd64-cpython-310\gensim\corpora\_mmreader.cp310-win_amd64.pyd : fatal error LNK1120: 1 unresolved externals
#       error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2022\\BuildTools\\VC\\Tools\\MSVC\\14.39.33519\\bin\\HostX86\\x64\\link.exe' failed with exit code 1120
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gensim
# ERROR: Could not build wheels for gensim, which is required to install pyproject.toml-based projects

# %%
# !pip install scipy==1.4.1
# Out:
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1.tar.gz (24.6 MB)
#      ---------------------------------------- 0.0/24.6 MB ? eta -:--:--
#      ---------------------------------------- 0.2/24.6 MB 5.9 MB/s eta 0:00:05
#       --------------------------------------- 0.4/24.6 MB 4.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.9/24.6 MB 6.2 MB/s eta 0:00:04
#      -- ------------------------------------- 1.4/24.6 MB 7.7 MB/s eta 0:00:04
#      --- ------------------------------------ 1.9/24.6 MB 8.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 2.7/24.6 MB 9.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 3.3/24.6 MB 10.1 MB/s eta 0:00:03
#      ------ --------------------------------- 4.1/24.6 MB 11.0 MB/s eta 0:00:02
#      ------- -------------------------------- 4.8/24.6 MB 11.4 MB/s eta 0:00:02
#      --------- ------------------------------ 5.6/24.6 MB 12.3 MB/s eta 0:00:02
#      ---------- ----------------------------- 6.3/24.6 MB 12.7 MB/s eta 0:00:02
#      ----------- ---------------------------- 7.2/24.6 MB 12.7 MB/s eta 0:00:02
#      ------------ --------------------------- 7.9/24.6 MB 13.4 MB/s eta 0:00:02
#      -------------- ------------------------- 8.7/24.6 MB 13.5 MB/s eta 0:00:02
#      --------------- ------------------------ 9.4/24.6 MB 13.6 MB/s eta 0:00:02
#      ---------------- ---------------------- 10.3/24.6 MB 14.2 MB/s eta 0:00:02
#      ----------------- --------------------- 10.8/24.6 MB 15.6 MB/s eta 0:00:01
#      ----------------- --------------------- 11.0/24.6 MB 15.6 MB/s eta 0:00:01
#      ----------------- --------------------- 11.0/24.6 MB 15.6 MB/s eta 0:00:01
#      ------------------ -------------------- 11.4/24.6 MB 13.4 MB/s eta 0:00:01
#      ------------------- ------------------- 12.2/24.6 MB 13.9 MB/s eta 0:00:01
#      -------------------- ------------------ 12.8/24.6 MB 13.9 MB/s eta 0:00:01
#      --------------------- ----------------- 13.7/24.6 MB 14.2 MB/s eta 0:00:01
#      ----------------------- --------------- 14.6/24.6 MB 14.2 MB/s eta 0:00:01
#      ------------------------ -------------- 15.3/24.6 MB 14.2 MB/s eta 0:00:01
#      ------------------------- ------------- 16.1/24.6 MB 14.2 MB/s eta 0:00:01
#      -------------------------- ------------ 16.8/24.6 MB 13.9 MB/s eta 0:00:01
#      --------------------------- ----------- 17.6/24.6 MB 13.9 MB/s eta 0:00:01
#      ----------------------------- --------- 18.4/24.6 MB 14.2 MB/s eta 0:00:01
#      ----------------------------- --------- 18.9/24.6 MB 13.6 MB/s eta 0:00:01
#      ------------------------------- ------- 19.5/24.6 MB 13.6 MB/s eta 0:00:01
#      -------------------------------- ------ 20.2/24.6 MB 13.6 MB/s eta 0:00:01
#      --------------------------------- ----- 20.9/24.6 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 21.6/24.6 MB 15.6 MB/s eta 0:00:01
#      ----------------------------------- --- 22.3/24.6 MB 15.6 MB/s eta 0:00:01
#      ------------------------------------ -- 23.1/24.6 MB 15.6 MB/s eta 0:00:01
#      ------------------------------------- - 23.9/24.6 MB 15.6 MB/s eta 0:00:01
#      --------------------------------------  24.5/24.6 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------- 24.6/24.6 MB 14.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [2119 lines of output]
#       Ignoring numpy: markers 'python_version == "3.5" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.5" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#       Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#       Collecting wheel
#         Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
#       Collecting setuptools
#         Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
#       Collecting Cython>=0.29.13
#         Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl.metadata (3.2 kB)
#       Collecting numpy==1.17.3
#         Downloading numpy-1.17.3.zip (6.4 MB)
#            ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#             --------------------------------------- 0.2/6.4 MB 4.6 MB/s eta 0:00:02
#            --- ------------------------------------ 0.5/6.4 MB 5.6 MB/s eta 0:00:02
#            -------- ------------------------------- 1.3/6.4 MB 10.4 MB/s eta 0:00:01
#            ----------- ---------------------------- 1.8/6.4 MB 10.7 MB/s eta 0:00:01
#            -------------- ------------------------- 2.3/6.4 MB 10.5 MB/s eta 0:00:01
#            -------------- ------------------------- 2.3/6.4 MB 10.5 MB/s eta 0:00:01
#            --------------- ------------------------ 2.4/6.4 MB 7.7 MB/s eta 0:00:01
#            ------------------------- -------------- 4.0/6.4 MB 11.2 MB/s eta 0:00:01
#            ----------------------------- ---------- 4.8/6.4 MB 11.7 MB/s eta 0:00:01
#            ---------------------------------- ----- 5.5/6.4 MB 12.1 MB/s eta 0:00:01
#            ------------------------------------- -- 6.0/6.4 MB 12.1 MB/s eta 0:00:01
#            ---------------------------------------- 6.4/6.4 MB 12.0 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting pybind11>=2.4.0
#         Downloading pybind11-2.12.0-py3-none-any.whl.metadata (9.5 kB)
#       Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
#       Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
#       Downloading Cython-3.0.10-cp310-cp310-win_amd64.whl (2.8 MB)
#          ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#          ---- ----------------------------------- 0.3/2.8 MB 17.3 MB/s eta 0:00:01
#          ---------- ----------------------------- 0.7/2.8 MB 7.4 MB/s eta 0:00:01
#          -------------------- ------------------- 1.4/2.8 MB 11.1 MB/s eta 0:00:01
#          --------------------------- ------------ 1.9/2.8 MB 11.3 MB/s eta 0:00:01
#          ----------------------------------- ---- 2.4/2.8 MB 11.1 MB/s eta 0:00:01
#          ---------------------------------------- 2.8/2.8 MB 10.4 MB/s eta 0:00:00
#       Downloading pybind11-2.12.0-py3-none-any.whl (234 kB)
#          ---------------------------------------- 0.0/235.0 kB ? eta -:--:--
#          ---------------------------------------- 235.0/235.0 kB 7.0 MB/s eta 0:00:00
#       Building wheels for collected packages: numpy
#         Building wheel for numpy (setup.py): started
#         Building wheel for numpy (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         Ã— python setup.py bdist_wheel did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [2040 lines of output]
#             Running from numpy source directory.
#             blas_opt_info:
#             blas_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             blis_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blis not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             openblas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#             get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#             customize GnuFCompiler
#             Could not locate executable g77
#             Could not locate executable f77
#             customize IntelVisualFCompiler
#             Could not locate executable ifort
#             Could not locate executable ifl
#             customize AbsoftFCompiler
#             Could not locate executable f90
#             customize CompaqVisualFCompiler
#             Could not locate executable DF
#             customize IntelItaniumVisualFCompiler
#             Could not locate executable efl
#             customize Gnu95FCompiler
#             Could not locate executable gfortran
#             Could not locate executable f95
#             customize G95FCompiler
#             Could not locate executable g95
#             customize IntelEM64VisualFCompiler
#             customize IntelEM64TFCompiler
#             Could not locate executable efort
#             Could not locate executable efc
#             customize PGroupFlangCompiler
#             Could not locate executable flang
#             don't know how to compile Fortran code on platform 'nt'
#               NOT AVAILABLE
#
#             atlas_3_10_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             atlas_blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             accelerate_info:
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Temp\pip-install-wisawh9o\numpy_ca5f4cc92674462a8688a58fec2f7152\numpy\distutils\system_info.py:690: UserWarning:
#                 Optimized (vendor) Blas libraries are not found.
#                 Falls back to netlib Blas library which has worse performance.
#                 A better performance should be easily gained by switching
#                 Blas library.
#               self.calc_info()
#             blas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries blas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Temp\pip-install-wisawh9o\numpy_ca5f4cc92674462a8688a58fec2f7152\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [blas]) or by setting
#                 the BLAS environment variable.
#               self.calc_info()
#             blas_src_info:
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Temp\pip-install-wisawh9o\numpy_ca5f4cc92674462a8688a58fec2f7152\numpy\distutils\system_info.py:690: UserWarning:
#                 Blas (http://www.netlib.org/blas/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [blas_src]) or by setting
#                 the BLAS_SRC environment variable.
#               self.calc_info()
#               NOT AVAILABLE
#
#             'svnversion' is not recognized as an internal or external command,
#             operable program or batch file.
#             non-existing path in 'numpy\\distutils': 'site.cfg'
#             lapack_opt_info:
#             lapack_mkl_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries mkl_rt not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             openblas_lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             openblas_clapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries openblas,lapack not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             flame_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries flame not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             atlas_3_10_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries tatlas,tatlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#               NOT AVAILABLE
#
#             atlas_3_10_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries satlas,satlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             <class 'numpy.distutils.system_info.atlas_3_10_info'>
#               NOT AVAILABLE
#
#             atlas_threads_info:
#             Setting PTATLAS=ATLAS
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries ptf77blas,ptcblas,atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             <class 'numpy.distutils.system_info.atlas_threads_info'>
#               NOT AVAILABLE
#
#             atlas_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack_atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries f77blas,cblas,atlas not found in C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\libs
#             <class 'numpy.distutils.system_info.atlas_info'>
#               NOT AVAILABLE
#
#             lapack_info:
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             customize MSVCCompiler
#               libraries lapack not found in ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib', 'C:\\', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\libs']
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Temp\pip-install-wisawh9o\numpy_ca5f4cc92674462a8688a58fec2f7152\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) libraries not found.
#                 Directories to search for the libraries can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack]) or by setting
#                 the LAPACK environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#             lapack_src_info:
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Temp\pip-install-wisawh9o\numpy_ca5f4cc92674462a8688a58fec2f7152\numpy\distutils\system_info.py:1712: UserWarning:
#                 Lapack (http://www.netlib.org/lapack/) sources not found.
#                 Directories to search for the sources can be specified in the
#                 numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#                 the LAPACK_SRC environment variable.
#               if getattr(self, '_calc_info_{}'.format(lapack))():
#               NOT AVAILABLE
#
#             C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\_distutils\dist.py:266: UserWarning: Unknown distribution option: 'define_macros'
#               warnings.warn(msg)
#             running bdist_wheel
#             running build
#             running config_cc
#             unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#             running config_fc
#             unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#             running build_src
#             build_src
#             building py_modules sources
#             creating build
#             creating build\src.win-amd64-3.1
#             creating build\src.win-amd64-3.1\numpy
#             creating build\src.win-amd64-3.1\numpy\distutils
#             building library "npymath" sources
#             No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#             C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\setuptools\_distutils\_msvccompiler.py:535: UserWarning: Fallback spawn triggered. Please update distutils monkeypatch.
#               warnings.warn("Fallback spawn triggered. Please update distutils monkeypatch.")
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /MANIFEST:EMBED,ID=1 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\lib\um\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64 _configtest.obj /OUT:_configtest.exe
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d _configtest.exe
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /MANIFEST:EMBED,ID=1 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\lib\um\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.22621.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\\lib\10.0.22621.0\\um\x64 _configtest.obj /OUT:_configtest.exe
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d _configtest.exe
#             creating build\src.win-amd64-3.1\numpy\core
#             creating build\src.win-amd64-3.1\numpy\core\src
#             creating build\src.win-amd64-3.1\numpy\core\src\npymath
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npymath\npy_math_internal.h
#               adding 'build\src.win-amd64-3.1\numpy\core\src\npymath' to include_dirs.
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npymath\ieee754.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npymath\npy_math_complex.c
#             None - nothing done with h_files = ['build\\src.win-amd64-3.1\\numpy\\core\\src\\npymath\\npy_math_internal.h']
#             building library "npysort" sources
#             creating build\src.win-amd64-3.1\numpy\core\src\common
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\common\npy_sort.h
#               adding 'build\src.win-amd64-3.1\numpy\core\src\common' to include_dirs.
#             creating build\src.win-amd64-3.1\numpy\core\src\npysort
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\quicksort.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\mergesort.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\timsort.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\heapsort.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\radixsort.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\common\npy_partition.h
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\selection.c
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\common\npy_binsearch.h
#             conv_template:> build\src.win-amd64-3.1\numpy\core\src\npysort\binsearch.c
#             None - nothing done with h_files = ['build\\src.win-amd64-3.1\\numpy\\core\\src\\common\\npy_sort.h', 'build\\src.win-amd64-3.1\\numpy\\core\\src\\common\\npy_partition.h', 'build\\src.win-amd64-3.1\\numpy\\core\\src\\common\\npy_binsearch.h']
#             building extension "numpy.core._dummy" sources
#             Generating build\src.win-amd64-3.1\numpy\core\include/numpy\config.h
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             _configtest.c
#             _configtest.c(1): fatal error C1083: Cannot open include file: 'endian.h': No such file or directory
#             failure.
#             removing: _configtest.c _configtest.obj
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             _configtest.c
#             _configtest.c(1): fatal error C1083: Cannot open include file: 'sys/endian.h': No such file or directory
#             failure.
#             removing: _configtest.c _configtest.obj
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             removing: _configtest.c _configtest.obj _configtest.obj.d
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tc_configtest.c /Fo_configtest.obj
#             success!
#             removing: _configtest.c _configtest.obj _configtest.obj.d
# ...
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Ibuild\src.win-amd64-3.1\numpy\core\src\umath -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Inumpy\core\include -Ibuild\src.win-amd64-3.1\numpy\core\include/numpy -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tcnumpy\core\src\multiarray\scalarapi.c /Fobuild\temp.win-amd64-cpython-310\Release\numpy\core\src\multiarray\scalarapi.obj
#             C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Ibuild\src.win-amd64-3.1\numpy\core\src\umath -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Inumpy\core\include -Ibuild\src.win-amd64-3.1\numpy\core\include/numpy -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tcbuild\src.win-amd64-3.1\numpy\core\src\multiarray\scalartypes.c /Fobuild\temp.win-amd64-cpython-310\Release\build\src.win-amd64-3.1\numpy\core\src\multiarray\scalartypes.obj
#             scalartypes.c
#             numpy\core\include\numpy/npy_3kcompat.h(210): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\common.h(239): warning C4244: 'return': conversion from 'npy_uintp' to 'int', possible loss of data
#             numpy\core\src\multiarray\common.h(307): warning C4244: 'return': conversion from 'npy_intp' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(475): warning C4996: 'PyUnicode_AsUnicode': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(481): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(475): warning C4996: 'PyUnicode_AsUnicode': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(476): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(481): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(509): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(510): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(1912): warning C4244: 'function': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(1912): warning C4244: 'function': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(1849): warning C4996: 'PyUnicode_AsUnicode': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(1850): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#             numpy\core\src\multiarray\scalartypes.c.src(2036): warning C4244: 'function': conversion from 'npy_double' to 'npy_float', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2039): warning C4244: 'function': conversion from 'npy_double' to 'npy_float', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2871): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2851): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(2871): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#             numpy\core\src\multiarray\scalartypes.c.src(3311): error C2440: 'function': cannot convert from 'double' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3311): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3311): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3320): error C2440: 'function': cannot convert from 'double' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3320): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3319): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3326): error C2440: 'function': cannot convert from 'double' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3326): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3325): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3311): error C2440: 'function': cannot convert from 'npy_longdouble' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3311): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3311): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3320): error C2440: 'function': cannot convert from 'npy_longdouble' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3320): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3319): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3326): error C2440: 'function': cannot convert from 'npy_longdouble' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3326): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3325): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(3341): error C2440: 'function': cannot convert from 'double' to 'PyObject *'
#             numpy\core\src\multiarray\scalartypes.c.src(3341): warning C4024: '_Py_HashDouble': different types for formal and actual parameter 1
#             numpy\core\src\multiarray\scalartypes.c.src(3341): error C2198: '_Py_HashDouble': too few arguments for call
#             numpy\core\src\multiarray\scalartypes.c.src(4558): warning C4244: 'return': conversion from 'npy_intp' to 'int', possible loss of data
#             error: Command "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -Ibuild\src.win-amd64-3.1\numpy\core\src\umath -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Inumpy\core\include -Ibuild\src.win-amd64-3.1\numpy\core\include/numpy -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\include -IC:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\Include -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -Ibuild\src.win-amd64-3.1\numpy\core\src\common -Ibuild\src.win-amd64-3.1\numpy\core\src\npymath -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.39.33519\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /Tcbuild\src.win-amd64-3.1\numpy\core\src\multiarray\scalartypes.c /Fobuild\temp.win-amd64-cpython-310\Release\build\src.win-amd64-3.1\numpy\core\src\multiarray\scalartypes.obj" failed with exit status 2
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for numpy
#         Running setup.py clean for numpy
#         error: subprocess-exited-with-error
#
#         Ã— python setup.py clean did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [10 lines of output]
#             Running from numpy source directory.
#
#             `setup.py clean` is not supported, use one of the following instead:
#
#               - `git clean -xdf` (cleans all files)
#               - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                                   files that aren't checked into the git repo)
#
#             Add `--force` to your command to use it anyway if you must (unsupported).
#
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed cleaning build dir for numpy
#       Failed to build numpy
#       ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import pandas as pd
import spacy 
from spacy import displacy

# %%
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaModel, CoherenceModel, LsiModel, HdpModel
import pyLDAvis
import pyLDAvis.gensim_models
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import gensim
#       2 from gensim.corpora import Dictionary
#       3 from gensim.models import LdaModel, CoherenceModel, LsiModel, HdpModel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gensim\matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (C:\Users\esthe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\linalg\__init__.py)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
df = pd.read_csv('rake_real.csv')

# %%
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = df.dropna()
#
# NameError: name 'df' is not defined

# %%
### CREATING A SMALLER DATASET TO TEST STUFF ###
# Separate the DataFrame into two subsets based on categories
true_df = df[df['type'] == 'True']
fake_df = df[df['type'] == 'Fake']

# Randomly sample an equal number of rows from each subset
sampled_true = true_df.sample(n=200, replace=False, random_state=42)
sampled_fake = fake_df.sample(n=200, replace=False, random_state=42)

# Combine the sampled rows into a single DataFrame
sampled_df = pd.concat([sampled_true, sampled_fake])

# Reset the index of the sampled DataFrame
sampled_df.reset_index(drop=True, inplace=True)

# %%
def remove_stopwords(doc):
    return ' '.join([token.text for token in nlp(doc) if not token.is_stop])

sampled_df['text'] = sampled_df['text'].apply(remove_stopwords)

# %% [markdown]
# ## bigram model

# %% [markdown]
# ## latent semantic indexing

# %% [markdown]
# ## LDA

# %% [markdown]
# ## viz with LDA
