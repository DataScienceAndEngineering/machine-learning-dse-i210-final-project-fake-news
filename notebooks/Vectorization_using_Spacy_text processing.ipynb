# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the dataset from the specified path
df = pd.read_csv('/content/preprocess_text_Spacy.csv', sep=',', encoding='utf-8', quotechar='"')

# %%
df.isnull().sum()
# Out:
# title               0
# text                0
# subject             0
# date                0
# type                0
# processed_Text    631
# dtype: int64
