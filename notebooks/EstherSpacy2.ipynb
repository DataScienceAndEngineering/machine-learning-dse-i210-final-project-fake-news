# %%
# !pip install -U pip setuptools wheel
# Out:
# ...
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 393.8 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 819.2 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.6/2.1 MB 3.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.5 MB/s eta 0:00:00
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# ...
#    ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#    ---------------------------------------- 65.8/65.8 kB ? eta 0:00:00
# ...

# %%
# !pip install -U spacy[cuda11x,transformers,lookups]

# %%
# !python -m spacy download en_core_web_trf
# Out:
# ...
#      ---------------------------------------- 0.0/457.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/457.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/457.4 MB 217.9 kB/s eta 0:35:00
#      -------------------------------------- 0.0/457.4 MB 220.2 kB/s eta 0:34:37
#      -------------------------------------- 0.1/457.4 MB 292.6 kB/s eta 0:26:04
#      -------------------------------------- 0.1/457.4 MB 547.6 kB/s eta 0:13:56
#      ---------------------------------------- 0.4/457.4 MB 1.7 MB/s eta 0:04:28
#      ---------------------------------------- 1.0/457.4 MB 3.7 MB/s eta 0:02:04
#      ---------------------------------------- 1.8/457.4 MB 5.6 MB/s eta 0:01:22
#      ---------------------------------------- 1.9/457.4 MB 5.7 MB/s eta 0:01:20
#      ---------------------------------------- 2.3/457.4 MB 5.7 MB/s eta 0:01:20
#      ---------------------------------------- 4.1/457.4 MB 8.8 MB/s eta 0:00:52
# ...

# %%
# !pip install spacy[cuda110]
# Out:
# ...
#   Using cached cupy_cuda110-12.3.0-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# ...
# Using cached cupy_cuda110-12.3.0-cp311-cp311-win_amd64.whl (60.4 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\esthe\\DSEI2100_Project\\machine-learning-dse-i210-final-project-fake-news\\.conda\\Lib\\site-packages\\cupy\\_core\\core.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import cupy as cp

# Try to create a simple CuPy array
try:
    arr = cp.zeros((3, 3))
    print("CuPy is installed and working correctly.")
except Exception as e:
    print("Error:", e)
    print("CuPy is not installed or not configured correctly.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\esthe\DSEI2100_Project\machine-learning-dse-i210-final-project-fake-news\.conda\Lib\site-packages\cupy\__init__.py:17
#      16 try:
# ---> 17     from cupy import _core  # NOQA
#      18 except ImportError as exc:
#
# File c:\Users\esthe\DSEI2100_Project\machine-learning-dse-i210-final-project-fake-news\.conda\Lib\site-packages\cupy\_core\__init__.py:3
#       1 # mypy: ignore-errors
# ----> 3 from cupy._core import core  # NOQA
#       4 from cupy._core import fusion  # NOQA
#
# File cupy\_core\core.pyx:1, in init cupy._core.core()
#
# File c:\Users\esthe\DSEI2100_Project\machine-learning-dse-i210-final-project-fake-news\.conda\Lib\site-packages\cupy\cuda\__init__.py:8
#       7 from cupy._environment import get_hipcc_path  # NOQA
# ----> 8 from cupy.cuda import compiler  # NOQA
# ...

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# Out:
# ...
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# c:\Users\esthe\DSEI2100_Project\machine-learning-dse-i210-final-project-fake-news\.conda\python.exe -m pip install --upgrade pip
# ...
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
# ...

# %%
# !pip install cupy
# Out:
# WARNING: Skipping cupy as it is not installed.
# ...
#   Using cached cupy-13.1.0.tar.gz (3.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for cupy
# Failed to build cupy
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [4111 lines of output]
#       Generating cache key from header files...
#       Cache key (1527 files matching C:\Users\esthe\AppData\Local\Temp\pip-install-ldjskhah\cupy_fc972dafdfd8430199c8257199efaf21\cupy\_core\include\**): 3f568024457b0157b890202c0a837884ca5823a9
#       Clearing directory: C:\Users\esthe\AppData\Local\Temp\pip-install-ldjskhah\cupy_fc972dafdfd8430199c8257199efaf21\cupy\.data
#       Looking for NVTX: C:\Program Files\NVIDIA Corporation\Nsight Systems *\target-windows-x64\nvtx
#       Using NVTX at: C:\Program Files\NVIDIA Corporation\Nsight Systems 2023.4.4\target-windows-x64\nvtx
# ...

# %%
# !pip install cupy --no-cache-dir

# %%
import spacy
spacy.require_gpu()
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import spacy
# ----> 2 spacy.require_gpu()
#       3 nlp = spacy.load("en_core_web_sm")
#
# File c:\Users\esthe\DSEI2100_Project\machine-learning-dse-i210-final-project-fake-news\.conda\Lib\site-packages\thinc\util.py:230, in require_gpu(gpu_id)
#     228     raise ValueError("Cannot use GPU, PyTorch is not installed")
#     229 elif platform.system() != "Darwin" and not has_cupy:
# --> 230     raise ValueError("Cannot use GPU, CuPy is not installed")
#     231 elif not has_gpu:
#     232     raise ValueError("No GPU devices detected")
#
# ValueError: Cannot use GPU, CuPy is not installed
